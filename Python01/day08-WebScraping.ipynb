# %%
# get req
import requests

r = requests.get('https://api.github.com/events')
# print(r)
# print(r.status_code)
if r.status_code == 200:
    print('Get sucsess')
    # print(r.headers)
    content_type = r.headers['content-type']
    # print(content_type)
    # print response
    print(r.text)

    if 'application/json' in r.headers['content-type']:
        data = r.json()
        print(data)

elif r.status_code == 404:
    print('Not found')
elif r.status_code == 403:
    print('fohibin')
elif r.status_code == 500:
    print('Serever Error')
# Out:
# Get sucsess
# ...

# %%
# post req
import requests

url = ('https://httpbin.org/post')
data = {'username' : 'user' , 'password' : 'pass'}
respons = requests.post(url , data)

if respons.status_code == 200:
    print('Login Succcessful')
    print(respons.text)
else:
    print('LoginFaild', respons.status_code)
# Out:
# Login Succcessful
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-677caf63-6429d5df6f44a8df1066a7ef"
#   },
#   "json": null,
#   "origin": "111.223.186.112",
#   "url": "https://httpbin.org/post"
# }

# %%
# url varible
import requests

url = 'https://example.com/search'
params = {'q':'python','category':'books'}

respons = requests.get(url, params=params)
if respons.status_code == 200:
    print('Succcessful')
    print(respons.text)
else:
    print('Faild', respons.status_code)
# Out:
# Faild 404

# %%
import requests

url = ('https://httpbin.org/get')
username = 'user'
password = 'pass'
respons = requests.get(url , auth=(username,password))

if respons.status_code == 200:
    print('Login Succcessful')
    print(respons.text)
else:
    print('LoginFaild', respons.status_code)
# Out:
# Login Succcessful
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-677cb633-70d8f0bf3c45392b26c9d5b8"
#   },
#   "origin": "111.223.186.112",
#   "url": "https://httpbin.org/get"
# }

# %%
# beautifulsoup4
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie&quot; class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie&quot; class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie&quot; class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc,'html.parser')
print(soup.title.text)
print(soup.a)
p_tag = soup.find('p')
print(p_tag)
p_tags = soup.find_all('p')
print(p_tags)
# Out:
# The Dormouse's story
# <a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>
# <p class="title"><b>The Dormouse's story</b></p>
# [<p class="title"><b>The Dormouse's story</b></p>, <p class="story">Once upon a time there were three little sisters; and their names were
# <a href='http://example.com/elsie" class=' id="link1" sister"="">Elsie</a>,
# <a href='http://example.com/lacie" class=' id="link2" sister"="">Lacie</a> and
# <a href='http://example.com/tillie" class=' id="link3" sister"="">Tillie</a>;
# and they lived at the bottom of a well.</p>, <p class="story">...</p>]

# %%
import requests
from bs4 import BeautifulSoup 

url = 'https://example.com'
respons = requests.get(url)

if respons.status_code == 200:
    soup = BeautifulSoup(respons.text,'html.parser')
    h1_tag = soup.find('h1')
    if h1_tag:
        print('h1_tag : ',h1_tag)
    else:
        print('h1_tag not found')
else:
    print('Faild !!',respons.status_code)
# Out:
# h1_tag :  <h1>Example Domain</h1>
